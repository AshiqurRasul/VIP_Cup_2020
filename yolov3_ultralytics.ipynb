# %%
# !git clone https://github.com/ultralytics/yolov3.git
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 9360, done.
# remote: Total 9360 (delta 0), reused 0 (delta 0), pack-reused 9360
# Receiving objects: 100% (9360/9360), 7.17 MiB | 8.71 MiB/s, done.
# Resolving deltas: 100% (6431/6431), done.

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 7335 (delta 40), reused 42 (delta 19), pack-reused 7255
# Receiving objects: 100% (7335/7335), 13.89 MiB | 13.11 MiB/s, done.
# Resolving deltas: 100% (4940/4940), done.
# /content/apex
# /usr/local/lib/python3.6/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# Created temporary directory: /tmp/pip-ephem-wheel-cache-70ka2zag
# Created temporary directory: /tmp/pip-req-tracker-4dem42y9
# Created requirements tracker '/tmp/pip-req-tracker-4dem42y9'
# Created temporary directory: /tmp/pip-install-xpdlifk4
# Processing /content/apex
#   Created temporary directory: /tmp/pip-req-build-o06c95su
# ...

# %%
# %cd /content/yolov3
# Out:
# /content/yolov3

# %%
# %cp  '/content/drive/My Drive/Classroom/ashiq_train.data' '/content/yolov3/data'
# %cp  '/content/drive/My Drive/Classroom/testing_list.shapes' '/content/yolov3/data'
# %cp  '/content/drive/My Drive/Classroom/testing_list.txt' '/content/yolov3/data'
# %cp  '/content/drive/My Drive/Classroom/training_list.txt' '/content/yolov3/data'
# %cp  '/content/drive/My Drive/Classroom/training_list.shapes' '/content/yolov3/data'
# %cp  '/content/drive/My Drive/Classroom/single_class.names' '/content/yolov3/data'
# %cp  '/content/drive/My Drive/Classroom/ashiqur_train.cfg' '/content/yolov3/cfg'

# %%
# !python3 train.py --data data/ashiq_train.data --cfg cfg/ashiqur_train.cfg --epochs 10 --weights '' --batch-size 32 --adam --multi-scale --name 'try01' --img-size 416
# %cp -r '/content/yolov3' '/content/drive/My Drive/Diabetic_Retinopathy'
# Out:
# Namespace(adam=True, batch_size=32, bucket='', cache_images=False, cfg='cfg/ashiqur_train.cfg', data='data/ashiq_train.data', device='', epochs=10, evolve=False, freeze_layers=False, img_size=[416], multi_scale=True, name='try01', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='')
# Using CUDA Apex device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# 2020-07-13 05:57:46.089965: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 222 layers, 6.15237e+07 parameters, 6.15237e+07 gradients
# Optimizer groups: 75 .bias, 75 Conv2d.weight, 72 other
# Caching labels /content/yolov3/data/training_list.txt (16997 found, 3 missing, 0 empty, 0 duplicate, for 17000 images): 100% 17000/17000 [3:09:45<00:00,  1.49it/s]
# ...
